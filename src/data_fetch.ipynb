# %% [markdown]
# ### Import libraries

# %%
import ee
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import datetime as dt

# Load environment variables from .env file
load_dotenv()
# Out:
# d:\09_Kiki\code\.venv\lib\site-packages\google\api_core\_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.11) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# True

# %% [markdown]
# ### Initialize earth engine

# %%
ee.Authenticate()   # Authenticate the Earth Engine API

# Initialize the Earth Engine API
try:
    ee.Initialize(project=os.getenv("GEE_PROJECT"))
    print("Earth Engine initialized")
except Exception as e:
    print("Error initializing Earth Engine: ", e)
    exit(1)
# Out:
# Earth Engine initialized

# %% [markdown]
# ### Location

# %%
locations = [
    # I. Timang Gajah 
    {'name': 'Kenine', 'lon': 96.791793, 'lat': 4.739783}, 
    {'name': 'Fajar Harapan', 'lon': 96.785601, 'lat': 4.740346}, 
    {'name': 'Damaran Baru', 'lon': 96.787009, 'lat': 4.745158},
    {'name': 'Pantan Pediangan', 'lon': 96.793414, 'lat': 4.768852},
    {'name': 'Bandar Lampahan', 'lon': 96.788870, 'lat': 4.749349},
    {'name': 'Rembune', 'lon': 96.795237, 'lat': 4.760899},
    {'name': 'Mude Benara', 'lon': 96.770665, 'lat': 4.747508},
    {'name': 'Bumi Ayu', 'lon': 96.76858737, 'lat': 4.73864171},
    {'name': 'Karang Jadi', 'lon': 96.77672175, 'lat': 4.75576727},
    {'name': 'Kampung Baru 76', 'lon': 96.75434232, 'lat': 4.7455993},
    {'name': 'Lampahan Timur', 'lon': 96.7755989, 'lat': 4.75897011},
    {'name': 'Lampahan', 'lon': 96.77316345, 'lat': 4.76183109},
    {'name': 'Bukit Mulie', 'lon': 96.77674763, 'lat': 4.76946389},
    {'name': 'Suka Damai', 'lon': 96.76018711, 'lat': 4.76837454},
    {'name': 'Sumber Jaya', 'lon': 96.76824235, 'lat': 4.77730412},
    {'name': 'Lampahan Barat', 'lon': 96.75249782, 'lat': 4.75657168},
    {'name': 'Mekar Ayu', 'lon': 96.76010277, 'lat': 4.76349219},
    {'name': 'Datu Beru', 'lon': 96.73538043, 'lat': 4.75453831},
    {'name': 'Timang Rasa', 'lon': 96.74142327, 'lat': 4.74579839},
    {'name': 'Kulem Parakanis', 'lon': 96.71705257, 'lat': 4.74894689},
    {'name': 'Linung Bale', 'lon': 96.73962486, 'lat': 4.76044489},
    {'name': 'Gunung Tunyang', 'lon': 96.73653418, 'lat': 4.7653093},
    {'name': 'Bukit Tunyang', 'lon': 96.72503904, 'lat': 4.76293671},
    {'name': 'Gegur Sepakat', 'lon': 96.71967104, 'lat': 4.75940556},
    {'name': 'Tunyang', 'lon': 96.73081114, 'lat': 4.76908237},
    {'name': 'Simpang Layang', 'lon': 96.73828145, 'lat': 4.7723849},
    {'name': 'Blang Rongka', 'lon': 96.7349608, 'lat': 4.78699163},
    {'name': 'Setie', 'lon': 96.74614608, 'lat': 4.79235503},
    {'name': 'Cekal Baru', 'lon': 96.70177518, 'lat': 4.75984463},
    {'name': 'Pantan Kemuning', 'lon': 96.71580886, 'lat': 4.78099981},

    # II. Permata 
    {'name': 'Buntul Peteri', 'lon': 96.91630384, 'lat': 4.82916041},
    {'name': 'Bale Musara', 'lon': 96.91791813, 'lat': 4.80235348},
    {'name': 'Jungke', 'lon': 96.93928833, 'lat': 4.78441851},
    {'name': 'Kepies', 'lon': 96.89303106, 'lat': 4.82902186},
    {'name': 'Seni Antara', 'lon': 96.89278575, 'lat': 4.85630569},
    {'name': 'Pantan Tengah Jaya', 'lon': 96.95295224, 'lat': 4.78964457},
    {'name': 'Ayu Ara', 'lon': 96.95749693, 'lat': 4.79140094},
    {'name': 'Rikit Musara', 'lon': 96.87539849, 'lat': 4.86706505},
    {'name': 'Suku Sara Tangke', 'lon': 96.97471246, 'lat': 4.81328252},
    {'name': 'Ramung Jaya', 'lon': 96.94402562, 'lat': 4.80427309},
    {'name': 'Timur Jaya', 'lon': 96.99534222, 'lat': 4.80533543},
    {'name': 'Ceding Ayu', 'lon': 96.92719750, 'lat': 4.8082609},
    {'name': 'Darul Aman', 'lon': 96.94075384, 'lat': 4.79835553},
    {'name': 'Burni Pase', 'lon': 96.91799166, 'lat': 4.85229443},
    {'name': 'Wih Tenang Uken', 'lon': 96.93300641, 'lat': 4.82487354},
    {'name': 'Bintang Permata', 'lon': 96.91218041, 'lat': 4.81183257},
    {'name': 'Uning Sejuk', 'lon': 96.96839169, 'lat': 4.81308348},
    {'name': 'Wih Tenang Toa/Bakongan Baru', 'lon': 96.97546798, 'lat': 4.79258484},
    {'name': 'Jelobok', 'lon': 96.95633826, 'lat': 4.833654},
    {'name': 'Penosan Jaya', 'lon': 96.96256371, 'lat': 4.83912228},
    {'name': 'Bener Pepanyi', 'lon': 96.89527241, 'lat': 4.79107643},
    {'name': 'Bintang Bener', 'lon': 96.89684603, 'lat': 4.80138459},
    {'name': 'Pemango', 'lon': 96.9500282, 'lat': 4.81328596},
    {'name': 'Gelampang Wih Tenang Uken', 'lon': 96.91585486, 'lat': 4.82014394},
    {'name': 'Bale Purnama', 'lon': 96.89019621, 'lat': 4.8168838},
    {'name': 'Temas Mumanang', 'lon': 96.98300554, 'lat': 4.83935834},
    {'name': 'Tawar Bengi', 'lon': 96.96388163, 'lat': 4.80938097},

    # III. Mesidah 
    {'name': 'Amor', 'lon': 97.02024548, 'lat': 4.78081686},
    {'name': 'Buntul Gayo', 'lon': 97.03021881, 'lat': 4.77300754},
    {'name': 'Weh Resap', 'lon': 97.05622665, 'lat': 4.76632831},
    {'name': 'Pantan Kuli', 'lon': 97.00058317, 'lat': 4.77715893},
    {'name': 'Cemparam Lama', 'lon': 96.96308367, 'lat': 4.76483384},
    {'name': 'Cemparam Pakat Jeroh', 'lon': 96.98024275, 'lat': 4.76428039},
    {'name': 'Cemparam Jaya', 'lon': 96.99402107, 'lat': 4.76801944},
    {'name': 'Jamur Atu', 'lon': 97.01214457, 'lat': 4.75407617},
    {'name': 'Simpang Renggali', 'lon': 97.00885966, 'lat': 4.77924328},
    {'name': 'Gunung Sayang', 'lon': 97.03761789, 'lat': 4.73715788},
    {'name': 'Uwer Tingkem', 'lon': 97.05219525, 'lat': 4.74881899},
    {'name': 'Perumpaken Benjadi', 'lon': 97.0738784, 'lat': 4.75536406},
    {'name': 'Simpur', 'lon': 97.12368649, 'lat': 4.77162662},
    {'name': 'Hakim Peteri Pintu', 'lon': 97.0936656, 'lat': 4.78873102},
    {'name': 'Sosial', 'lon': 97.00492238, 'lat': 4.73314358},

    # IV. Wih Pesam 
    {'name': 'Wih Pesam', 'lon': 96.82993358, 'lat': 4.76430678},
    {'name': 'Blang Benara', 'lon': 96.75268256, 'lat': 4.72055208},
    {'name': 'Blang Paku', 'lon': 96.74511767, 'lat': 4.71978997},
    {'name': 'Blang Kucak', 'lon': 96.76283172, 'lat': 4.72193506},
    {'name': 'Burni Telong', 'lon': 96.81193307, 'lat': 4.71705567},
    {'name': 'Cinta Damai', 'lon': 96.79118138, 'lat': 4.71842202},
    {'name': 'Jamur Ujung', 'lon': 96.8144479, 'lat': 4.70785203},
    {'name': 'Kebun Baru', 'lon': 96.78617453, 'lat': 4.72884948},
    {'name': 'Lut Kucak', 'lon': 96.8029414, 'lat': 4.71608963},
    {'name': 'Pante Raya', 'lon': 96.81063689, 'lat': 4.73452296},
    {'name': 'Bukit Pepanyi', 'lon': 96.81500627, 'lat': 4.68488818},
    {'name': 'Simpang Teritit', 'lon': 96.83478864, 'lat': 4.68426156},
    {'name': 'Suka Jadi', 'lon': 96.7938269, 'lat': 4.70050684},
    {'name': 'Suka Makmur Timur', 'lon': 96.76084412, 'lat': 4.73254538},
    {'name': 'Suka Makmur', 'lon': 96.73453657, 'lat': 4.73527237},
    {'name': 'Suka Ramai Atas', 'lon': 96.82349281, 'lat': 4.69736606},
    {'name': 'Suka Ramai Bawah', 'lon': 96.81599505, 'lat': 4.69812756},
    {'name': 'Syura Jadi', 'lon': 96.8072294, 'lat': 4.69728007},
    {'name': 'Wono Sobo', 'lon': 96.82578724, 'lat': 4.72019486},
    {'name': 'Simpang Antara', 'lon': 96.78293559, 'lat': 4.720332},
    {'name': 'Merie Satu', 'lon': 96.827641, 'lat':4.6772935},
    {'name': 'Jamur Uluh', 'lon': 96.82720282, 'lat': 4.69000023},
    {'name': 'Simpang Balik', 'lon': 96.80601549, 'lat': 4.73920594},
    {'name': 'Bener Mulie', 'lon': 96.79318246, 'lat': 4.73670909},
    {'name': 'Bener Ayu', 'lon': 96.77384871, 'lat': 4.72493994},
    {'name': 'Gegerung', 'lon': 96.83352744, 'lat': 4.69004941},

    # V. Syiah Utama 
    {'name': 'Tembolon', 'lon': 97.0429566, 'lat': 4.70465236},
    {'name': 'Rusip', 'lon': 97.15285582, 'lat': 4.75264341},
    {'name': 'Wihni Durin', 'lon': 97.12075291, 'lat': 4.69377708},
    {'name': 'Blang Panu', 'lon': 97.21658863, 'lat': 4.71419474},
    {'name': 'Rata Mulie', 'lon': 97.18637344, 'lat': 4.63087516},

    # VI. Bukit 
    {'name': 'Bale Redelong', 'lon': 96.859784, 'lat': 4.743096},
    {'name': 'Ujung Gele', 'lon': 96.883569, 'lat': 4.723777},
    {'name': 'Bale Atu', 'lon': 96.848519, 'lat': 4.733009},
    {'name': 'Babussalam', 'lon': 96.865314, 'lat': 4.730246},
    {'name': 'Hakim Tungul Naru', 'lon': 96.854909, 'lat': 4.737333},
    {'name': 'Blang Panas', 'lon': 96.853911, 'lat': 4.676235},
    {'name': 'Blang Tampu', 'lon': 96.843518, 'lat': 4.689856},
    {'name': 'Serule Kayu', 'lon': 96.863022, 'lat': 4.699039},
    {'name': 'Kute Tanyung', 'lon': 96.863423, 'lat': 4.705163},
    {'name': 'Delung Tue', 'lon': 96.892693, 'lat': 4.708959},
    {'name': 'Delung Asli', 'lon': 96.897309, 'lat': 4.718246},
    {'name': 'Pilar Jaya', 'lon': 96.911777, 'lat': 4.699440},
    {'name': 'Uning Bersah', 'lon': 96.861582, 'lat': 4.682489},
    {'name': 'Uning Teritit', 'lon': 96.874338, 'lat': 4.676822},
    {'name': 'Bathin Wih Pongas', 'lon': 96.884916, 'lat': 4.707377},
    {'name': 'Tingkem Asli', 'lon': 96.881102, 'lat': 4.698884},
    {'name': 'Tingkem Benyer', 'lon': 96.859125, 'lat': 4.715768},
    {'name': 'Tingkem Bersatu', 'lon': 96.895375, 'lat': 4.678536},
    {'name': 'Blang Sentang', 'lon': 96.876180, 'lat': 4.717535},
    {'name': 'Reje Guru', 'lon': 96.880569, 'lat': 4.719955},
    {'name': 'Mutiara Baru', 'lon': 96.832536, 'lat': 4.674667},
    {'name': 'Bukit Bersatu', 'lon': 96.838629, 'lat': 4.675184},
    {'name': 'Blang Ara', 'lon': 96.892775, 'lat': 4.739693},
    {'name': 'Waq Pondok Sayur', 'lon': 96.878891, 'lat': 4.753434},
    {'name': 'Panji Mulia I', 'lon': 96.870119, 'lat': 4.744511},
    {'name': 'Panji Mulia II', 'lon': 96.878859, 'lat': 4.745205},
    {'name': 'Rembele', 'lon': 96.839985, 'lat': 4.707438},
    {'name': 'Karang Rejo', 'lon': 96.832748, 'lat': 4.716259},
    {'name': 'Kute Kering', 'lon': 96.851239, 'lat': 4.708224},
    {'name': 'Kute Lintang', 'lon': 96.857507, 'lat': 4.703057},
    {'name': 'Isaq Busur', 'lon': 96.887867, 'lat': 4.728735},
    {'name': 'Meluem', 'lon': 96.887556, 'lat': 4.736049},
    {'name': 'Bujang', 'lon': 96.874519, 'lat': 4.734565},
    {'name': 'Godang', 'lon': 96.882908, 'lat': 4.732896},
    {'name': 'Uring', 'lon': 96.869154, 'lat': 4.717616},
    {'name': 'Kenawat Redelong', 'lon': 96.895701, 'lat': 4.729220},
    {'name': 'Paya Gajah', 'lon': 96.868209, 'lat': 4.722918},
    {'name': 'Pasar Simpang Tiga', 'lon': 96.873369, 'lat': 4.724551},
    {'name': 'Sedie Jadi', 'lon': 96.884496, 'lat': 4.767926},
    {'name': 'Mupakat Jadi', 'lon': 96.892816, 'lat': 4.747189},

    # VII. Bener Kelipah 
    {'name': 'Nosar Baru', 'lon': 96.899266, 'lat': 4.783970},
    {'name': 'Nosar Tawar Jaya', 'lon': 96.909075, 'lat': 4.780137},
    {'name': 'Bandar Jaya', 'lon': 96.899273, 'lat': 4.773663},
    {'name': 'Lot Bener Kelpah', 'lon': 96.915378, 'lat': 4.775660},
    {'name': 'Bener Kelipah Utara', 'lon': 96.927991, 'lat': 4.779027},
    {'name': 'Bener Kelipah Selatan', 'lon': 96.927829, 'lat': 4.771961},
    {'name': 'Gunung Musara', 'lon': 96.931729, 'lat': 4.766124},
    {'name': 'Jongok Meluem', 'lon': 96.905975, 'lat': 4.762749},
    {'name': 'Kala Tenang', 'lon': 96.936907, 'lat': 4.773766},
    {'name': 'Bintang Musara', 'lon': 96.954481, 'lat': 4.759372},
    {'name': 'Suku Bener', 'lon': 96.911664, 'lat': 4.767554},
    {'name': 'Bener Lukup', 'lon': 96.919081, 'lat': 4.767692},

    # VIII. Bandar 
    {'name': 'Pondok Baru', 'lon': 96.917074, 'lat': 4.759042},
    {'name': 'Janarata', 'lon': 96.913579, 'lat': 4.757887},
    {'name': 'Mutiara', 'lon': 96.909455, 'lat': 4.756274},
    {'name': 'Puja Mulia', 'lon': 96.919504, 'lat': 4.753870},
    {'name': 'Purwosari', 'lon': 96.911019, 'lat': 4.750103},
    {'name': 'Tawar Sedenge', 'lon': 96.916351, 'lat': 4.745633},
    {'name': 'Simpang Utama', 'lon': 96.905856, 'lat': 4.754306},
    {'name': 'Makmur Sentosa', 'lon': 96.910031, 'lat': 4.744756},
    {'name': 'Pondok Gajah', 'lon': 96.898520, 'lat': 4.750796},
    {'name': 'Bathin Baru', 'lon': 96.897777, 'lat': 4.762875},
    {'name': 'Suku Wih Ilang', 'lon': 96.900233, 'lat': 4.740012},
    {'name': 'Gele Semayang', 'lon': 96.905605, 'lat': 4.741120},
    {'name': 'Bukit Wih Ilang', 'lon': 96.906487, 'lat': 4.731241},
    {'name': 'Bahgie Bertona', 'lon': 96.923240, 'lat': 4.760725},
    {'name': 'Pondok Ulung', 'lon': 96.929889, 'lat': 4.757788},
    {'name': 'Kala Nempan', 'lon': 96.934965, 'lat': 4.756713},
    {'name': 'Pakat Jeroh', 'lon': 96.941127, 'lat': 4.763286},
    {'name': 'Selisih Mara', 'lon': 96.947187, 'lat': 4.762899},
    {'name': 'Selamat Rejo', 'lon': 96.951196, 'lat': 4.749915},
    {'name': 'Hakim Wih Ilang', 'lon': 96.916107, 'lat': 4.730100},
    {'name': 'Lewa Jadi', 'lon': 96.924436, 'lat': 4.723349},
    {'name': 'Gunung Antara', 'lon': 96.929013, 'lat': 4.711318},
    {'name': 'Remang Ketike Jaya', 'lon': 96.929046, 'lat': 4.730152},
    {'name': 'Tanjung Pura', 'lon': 96.936098, 'lat': 4.731229},
    {'name': 'Beranun Teleden', 'lon': 96.921829, 'lat': 4.736637},
    {'name': 'Keramat Jaya', 'lon': 96.927714, 'lat': 4.743501},
    {'name': 'Jadi Sepakat', 'lon': 96.926994, 'lat': 4.749781},
    {'name': 'Sidodadi', 'lon': 96.936565, 'lat': 4.749104},
    {'name': 'Petukel Blang Jorong', 'lon': 96.944519, 'lat': 4.741491},
    {'name': 'Paya Baning', 'lon': 96.950885, 'lat': 4.734360},
    {'name': 'Wonosari', 'lon': 96.948966, 'lat': 4.726733},
    {'name': 'Tansaran Bidin', 'lon': 96.953303, 'lat': 4.712659},
    {'name': 'Blang Pulo', 'lon': 96.964329, 'lat': 4.747545},
    {'name': 'Sinar Jaya Paya Ringkel', 'lon': 96.970130, 'lat': 4.741272},
    {'name': 'Muyang Kute Mangku', 'lon': 96.971073, 'lat': 4.725697},

    # IX. Gajah Putih 
    {'name': 'Gajah Putih', 'lon': 96.763472, 'lat': 4.817659},
    {'name': 'Simpang Rahmat', 'lon': 96.715728, 'lat': 4.817977},
    {'name': 'Reronga', 'lon': 96.740187, 'lat': 4.820639},
    {'name': 'Gayo Setie', 'lon': 96.767637, 'lat': 4.809431},
    {'name': 'Umah Besi', 'lon': 96.725266, 'lat': 4.806326},
    {'name': 'Meriah Jaya', 'lon': 96.709179, 'lat': 4.796441},
    {'name': 'Timang Gajah', 'lon': 96.734719, 'lat': 4.801899},
    {'name': 'Alam Jaya', 'lon': 96.745384, 'lat': 4.799346},
    {'name': 'Pante Karya', 'lon': 96.767486, 'lat': 4.797610},
    {'name': 'Pantan Lues', 'lon': 96.773536, 'lat': 4.790530},

    # X. Pintu Rime Gayo 
    {'name': 'Bintang Berangun', 'lon': 96.775237, 'lat': 4.887514},
    {'name': 'Pulo Intan', 'lon': 96.758763, 'lat': 4.835325},
    {'name': 'Singah Mulo', 'lon': 96.745337, 'lat': 4.851007},
    {'name': 'Alur Cincin', 'lon': 96.733389, 'lat': 4.894571},
    {'name': 'Musara 58', 'lon': 96.743749, 'lat': 4.844967},
    {'name': 'Uning Mas', 'lon': 96.808029, 'lat': 4.871172},
    {'name': 'Blang Rakal', 'lon': 96.727077, 'lat': 4.905340},
    {'name': 'Bener Meriah', 'lon': 96.741036, 'lat': 4.878909},
    {'name': 'Wih Porak', 'lon': 96.773520, 'lat': 4.867448},
    {'name': 'Alur Gading', 'lon': 96.714576, 'lat': 4.873271},
    {'name': 'Ulu Naron', 'lon': 96.762849, 'lat': 4.929295},
    {'name': 'Perdamaian', 'lon': 96.78084294, 'lat': 4.90521171},
    {'name': 'Rime Raya', 'lon': 96.72354601, 'lat': 4.83444156},
    {'name': 'Taman Firdaus', 'lon': 96.77966649, 'lat': 4.87532491},
    {'name': 'Pantan Sinaku', 'lon': 96.80687001, 'lat': 4.91337833},
    {'name': 'Rata Ara', 'lon': 96.77370354, 'lat': 4.85441499},
    {'name': 'Simpang Lancang', 'lon': 96.72105543, 'lat': 4.88266704},
    {'name': 'Pancar Jelobok', 'lon': 96.78801122, 'lat': 4.91606068},
    {'name': 'Blang Ara', 'lon': 96.72637027, 'lat': 4.84975976},
    {'name': 'Gemasih', 'lon': 96.74872958, 'lat': 4.82697039},
]

print(len(locations))
# Out:
# 220

# %% [markdown]
# ### Data Extraction

# %%
# Date range (YYYY-MM-DD)
start_date = '2020-01-01'
end_date = '2024-12-31'

# Load ERA5-Land dataset
era5 = ee.ImageCollection('ECMWF/ERA5_LAND/DAILY_AGGR')

# Select climate variables
climate_vars = era5.select([
    'total_precipitation_sum',                    # Rainfall (m)
    'temperature_2m',                             # Temperature (K)
    'dewpoint_temperature_2m',                    # Dewpoint temperature (K)
    'surface_net_solar_radiation_sum',            # Net absorbed radiation
    'volumetric_soil_water_layer_1',              # Soil moisture (m³/m³), ~0–7 cm
    'u_component_of_wind_10m',                    # Wind u-component (m/s)
    'v_component_of_wind_10m',                    # Wind v-component (m/s)
    'temperature_2m_max',                         # For DTR
    'temperature_2m_min',                         # For DTR
])

# Filter by date
filtered = climate_vars.filterDate(start_date, end_date)

# Function to extract data for one location
def extract_location_data(location):
    print(f"Processing {location['name']}...")
    
    # Create point geometry
    point = ee.Geometry.Point([location['lon'], location['lat']])
    
    # Function to extract values for each image
    def extract_values(image):
        # Reduce to point
        values = image.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=point,
            scale=11132  # ERA5-Land native resolution (~11km)
        )
        
        # Get date
        date = ee.Date(image.get('system:time_start'))
        
        # Create feature with all properties
        return ee.Feature(None, {
            'date': date.format('YYYY-MM-dd'),
            'location': location['name'],
            'longitude': location['lon'],
            'latitude': location['lat'],
            'rainfall_m': values.get('total_precipitation_sum'),
            'temperature_k': values.get('temperature_2m'),
            'dewpoint_k': values.get('dewpoint_temperature_2m'),
            'surface_net_solar_radiation_sum': values.get('surface_net_solar_radiation_sum'),
            'volumetric_soil_water_layer_1': values.get('volumetric_soil_water_layer_1'),
            'u_wind_10m': values.get('u_component_of_wind_10m'),
            'v_wind_10m': values.get('v_component_of_wind_10m'),
            'temperature_2m_max': values.get('temperature_2m_max'),
            'temperature_2m_min': values.get('temperature_2m_min'),
        })
    
    # Map over all images
    features = filtered.map(extract_values)
    
    # Convert to list and get info
    feature_list = features.toList(features.size())
    return feature_list.getInfo()

# Collect data for all locations
all_data = []

for location in locations:
    location_data = extract_location_data(location)
    
    # Extract properties from each feature
    for feature in location_data:
        props = feature['properties']
        all_data.append(props)

# Convert to pandas DataFrame
df = pd.DataFrame(all_data)

# --- Unit Conversions ---
df['rainfall_mm'] = df['rainfall_m'] * 1000  # Convert m to mm
df['temperature_celsius'] = df['temperature_k'] - 273.15  # Convert K to °C
df['dewpoint_celsius'] = df['dewpoint_k'] - 273.15  # Convert K to °C
df['soil_moisture_percent'] = df['volumetric_soil_water_layer_1'] * 100  # fraction → %
# Net radiation
df['net_solar_rad_kwh_m2'] = df['surface_net_solar_radiation_sum'] / 3_600_000
# Calculate wind speed (m/s)
df['wind_speed_10m'] = np.sqrt(df['u_wind_10m']**2 + df['v_wind_10m']**2)
# Diurnal Temperature Range
df['tmax_celsius'] = df['temperature_2m_max'] - 273.15
df['tmin_celsius'] = df['temperature_2m_min'] - 273.15
df['dtr_celsius'] = df['tmax_celsius'] - df['tmin_celsius']
# Vapor Pressure Deficit (kPa)
df['es'] = 0.6108 * np.exp(17.27 * df['temperature_celsius'] / (df['temperature_celsius'] + 237.3))
df['ea'] = 0.6108 * np.exp(17.27 * df['dewpoint_celsius'] / (df['dewpoint_celsius'] + 237.3))
df['vpd_kpa'] = df['es'] - df['ea']


# Calculate relative humidity using Magnus formula
def calculate_relative_humidity(temp_c, dewpoint_c):
    a = 17.27
    b = 237.7
    alpha_temp = (a * temp_c) / (b + temp_c)
    alpha_dewpoint = (a * dewpoint_c) / (b + dewpoint_c)
    rh = 100 * np.exp(alpha_dewpoint - alpha_temp)
    return rh

df['relative_humidity_percent'] = calculate_relative_humidity(
    df['temperature_celsius'], 
    df['dewpoint_celsius']
)

# Final column selection and ordering
df_final = df[[
    'date', 'location', 'latitude', 'longitude',
    'rainfall_mm', 'temperature_celsius', 'relative_humidity_percent', 
    'net_solar_rad_kwh_m2', 'wind_speed_10m', 'soil_moisture_percent', 
    'dtr_celsius', 'vpd_kpa', 
]].copy()

# Sort and reset index
df_final = df_final.sort_values(['location', 'date']).reset_index(drop=True)

# Handle potential missing values (e.g., due to negative precipitation or gaps)
df_final = df_final.replace(-np.inf, np.nan).replace(np.inf, np.nan)

# Save to CSV
output_filename = f'../data/climateData_BenerMeriah_{start_date}_{end_date}.csv'
df_final.to_csv(output_filename, index=False)

print(f"\nData extraction complete!")
print(f"Total records: {len(df_final)}")    
print(f"Saved to: {output_filename}")

# %%
print("Shape:", df_final.shape)
